# %%
import sys
sys.path.append("..")
from classes.preprocessing import CalciMetrics

# %%
path_to_data="/Users/lutz/Documents/CalciMetrics/CalciMetrics/test_data"

cc=CalciMetrics(path_to_data)

cc.import_data(frames_to_seconds=True, first_col_frames=True, fps_rate=1.667)
# Out:
# Data has been successfully imported. The names of your experiments are:
# Results_dish4.csv
# Results_Dish5.csv
# Results_Dish2.csv
# Results_Dish1.csv

# %%
cc.show_plot('Results_Dish5.csv')
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="a5d89ac7-540c-42af-aaaf-79296c813bc8">Loading BokehJS ...</span>
#     </div>
#   <div id="f3b7bd36-3218-4f43-b012-90de7f41ff34" data-root-id="p1223" style="display: contents;"></div>

# %%
excluded_rois_dict={'Results_dish4.csv':['Mean2', 'Mean4'],
                    'Results_Dish5.csv':['Mean13', 'Mean17']}

# %%
cc.exclude_rois(excluded_rois_dict)
cc.dff_calc()

# %%
cc.show_plot('Results_Dish5.csv')
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="fe956c9f-2bd3-4d7e-ae82-8263e6ca6b79">Loading BokehJS ...</span>
#     </div>
#   <div id="ffbf97c5-0541-49b6-af9d-170d32dd5c90" data-root-id="p1867" style="display: contents;"></div>

# %%
cc.save(filename='Test_project', save_trials_to_csv=True)
